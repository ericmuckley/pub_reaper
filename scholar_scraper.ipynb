# %% [markdown]
# # Google scholar scraper
#
# Getting publication information from Google Scholar is difficult because
# search results only show 10 publications per page, and results cannot
# be exported for further analysis.
#
# This notebook uses the Selenium Python wrapper to open Google Chrome,
# navigate to Google Scholar, search a topic, pull citaation information
# from each result, navigate to the next page, pull more results, and
# finally saves assembled citation information into a Pandas DataFrame for
# export as an ASCII text file.

# %%
import os, re, time
import numpy as np
import pandas as pd
from selenium import webdriver
import scholar_scrape_methods as ssm

# %% [markdown]
# ## Specifiy a topic to search on Google Scholar

# %%
topic = 'PEDOT:PSS'

# %% [markdown]
# ## Open browser, go to Scholar, and search topic

# %%
chromedriver_path = os.path.join(os.getcwd(), 'chromedriver.exe')

browser = webdriver.Chrome(executable_path=chromedriver_path)

# go to the url, query a topic, and submit the query
browser.get('https://scholar.google.com/')
query = browser.find_element_by_id('gs_hdr_tsi')
query.send_keys(topic)
query.submit()
time.sleep(2)

# %% [markdown]
# ## Read intial search results page

# %%
try:
    total_search_results = ssm.get_total_search_results(browser)
    max_pages = int(np.floor(total_search_results / 10))
    print('Total search results: {}'.format(total_search_results))
    print('Maximum results pages: {}'.format(max_pages))
except IndexError:
    print('Google has created a Recaptcha testfor you.')
    print('Please complete the test in the bowser window')
    print('and rerun this code and everything below it.')
# Out:
# Total search results: 103000
# Maximum results pages: 10300

# %% [markdown]
# ## Collect citation information from each publication

# %%
all_citations = []

for page_idx in range(10):
    print('reading page {}...'.format(1+page_idx))
    try:
        time.sleep(1)
        page_citations = ssm.get_citations(browser)
        all_citations += page_citations
        time.sleep(1)
        ssm.move_to_next_page(browser)
    except IndexError:
        time.sleep(3)
    time.sleep(1)

print('\nAcquired {} total citations'.format(len(all_citations)))
# Out:
# reading page 1...
# acquired 10 citations
# reading page 2...
# acquired 10 citations
# reading page 3...
# acquired 10 citations
# reading page 4...
# acquired 10 citations
# reading page 5...
# acquired 10 citations
# reading page 6...
# acquired 10 citations
# reading page 7...
# reading page 8...
# reading page 9...
# reading page 10...
#
# Acquired 60 total citations

# %% [markdown]
# ## Assemble results into Pandas DataFrame

# %%
df = pd.DataFrame([c.split('"') for c in all_citations],
                  columns=['author', 'title', 'pub'])
df['title'] = [t[1:-1] if t.startswith(' ') else t[:-1] for t in df['title']]
df['author'] = [a[:-1] for a in df['author']]
df['pub'] = [p[:-1] for p in df['pub']]
df['year'] = [int(re.split('\(+(\d+)\)', p)[-2]) for p in df['pub']]

# %%
df
# Out:
#                                                author  \
# 0   Lang, Udo, Elisabeth Müller, Nicola Naujoks, a...
# 1   Hong, Wenjing, Yuxi Xu, Gewu Lu, Chun Li, and ...
# 2   Nardes, A. Mantovani, Martijn Kemerink, René A...
# 3     Hwang, Jaehyung, Fabrice Amy, and Antoine Kahn.
# 4   Nardes, A. Mantovani, M. Kemerink, M. M. De Ko...
# 5   Vitoratos, E., S. Sakkopoulos, Evangelos Dalas...
# 6   Jönsson, S. K. M., Jonas Birgerson, Xavier Cri...
# 7           Lang, Udo, Nicola Naujoks, and Jurg Dual.
# 8   Timpanaro, S., Martijn Kemerink, F. J. Touwsla...
# 9   Greczynski, Grzegorz, Th Kugler, and W. R. Sal...
# 10  Takano, Takumi, Hiroyasu Masunaga, Akihiko Fuj...
# 11  Eom, Seung Hun, S. Senthilarasu, Periyayya Uth...
# 12  Kim, Nara, Seyoung Kee, Seoung Ho Lee, Byoung ...
# 13  Louwet, Frank, L. Groenendaal, Jan DHaen, Jean...
# 14  Alemu, Desalegn, Hung-Yu Wei, Kuo-Chuan Ho, an...
# 15  Vosgueritchian, Michael, Darren J. Lipomi, and...
# 16  Bae, Eun Jin, Young Hun Kang, Kwang-Suk Jang, ...
# 17  Sun, Kuan, Shupeng Zhang, Pengcheng Li, Yijie ...
# 18  Nardes, Alexandre Mantovani, Rene AJ Janssen, ...
# 19  Greczynski, G., Th Kugler, M. Keil, Wojciech O...
# 20  Huang, Jingsong, Paul F. Miller, John C. de Me...
# 21  De Kok, M. M., M. Buechel, S. I. E. Vulto, P. ...
# 22                   Xia, Yijie, and Jianyong Ouyang.
# 23  Kim, Yong Hyun, Christoph Sachse, Michael L. M...
# 24  Nardes, A. M., M. Kemerink, and R. A. J. Janssen.
# 25  Crispin, Xavier, F. L. E. Jakobsson, Annica Cr...
# 26  Lipomi, Darren J., Jennifer A. Lee, Michael Vo...
# 27  Kemerink, Martijn, S. Timpanaro, M. M. De Kok,...
# 28  Zhang, B., J. Sun, H. E. Katz, F. Fang, and R....
# 29  Shi, Hui, Congcong Liu, Qinglin Jiang, and Jin...
# 30  Snaith, Henry J., Henry Kenrick, Marco Chiesa,...
# 31  Na, Seok-In, Gunuk Wang, Seok-Soon Kim, Tae-Wo...
# 32  Gkoupidenis, Paschalis, Nathan Schaefer, Benja...
# 33  Wei, Qingshuo, Masakazu Mukaida, Yasuhisa Nait...
# 34  Kim, Youngkyoo, Amy M. Ballantyne, Jenny Nelso...
# 35  Taylor, Priscilla G., Jin‐Kyun Lee, Alexander ...
# 36     Okuzaki, Hidenori, Yuko Harashina, and Hu Yan.
# 37  Friedel, Bettina, Panagiotis E. Keivanidis, Th...
# 38  Fung, Dixon DS, Linfang Qiao, Wallace CH Choy,...
# 39       Okuzaki, H., H. Suzuki, and T. J. S. M. Ito.
# 40                       Kuş, Mahmut, and Salih Okur.
# 41  Cho, Chung-Ki, Woo-Jin Hwang, Kyoungtae Eun, S...
# 42                                  Ouyang, Jianyong.
# 43  Latessa, G., F. Brunetti, A. Reale, G. Saggio,...
# 44  Luo, Jinji, Detlef Billep, Thomas Waechtler, T...
# 45  Greco, Francesco, Alessandra Zucca, Silvia Tac...
# 46  Yee, Shannon K., Nelson E. Coates, Arun Majumd...
# 47  Park, Hongkwan, Seung Hwan Lee, Felix Sunjoo K...
# 48  Zhang, Wenfeng, Baofeng Zhao, Zhicai He, Xueme...
# 49  Seekaew, Yotsarayuth, Shongpun Lokavee, Ditsay...
# 50  Weickert, Jonas, Haiyan Sun, Claudia Palumbiny...
# 51  Liu, Zhaoyang, Khaled Parvez, Rongjin Li, Renh...
# 52  Thomas, Joseph Palathinkal, Liyan Zhao, Donald...
# 53  Döbbelin, Markus, Rebeca Marcilla, Maitane Sal...
# 54  Tait, Jeffrey G., Brian J. Worfolk, Samuel A. ...
# 55  Dimitriev, O. P., D. A. Grinko, Yu V. Noskov, ...
# 56                     Yan, Hu, and Hidenori Okuzaki.
# 57       Stöcker, Thomas, Anna Köhler, and Ralf Moos.
# 58  Pingree, Liam SC, Bradley A. MacLeod, and Davi...
# 59  Hu, Ziyang, Jianjun Zhang, Zhihong Hao, and Yi...
#
#                                                 title  \
# 0   Microscopical investigations of PEDOT: PSS thi...
# 1   Transparent graphene/PEDOT–PSS composite films...
# 2   Microscopic understanding of the anisotropic c...
# 3   Spectroscopic study on sputtered PEDOT· PSS: R...
# 4   Conductivity, work function, and environmental...
# 5        Thermal degradation mechanisms of PEDOT: PSS
# 6   The effects of solvents on the morphology and ...
# 7   Mechanical characterization of PEDOT: PSS thin...
# 8   Morphology and conductivity of PEDOT/PSS films...
# 9   Characterization of the PEDOT-PSS system by me...
# 10  PEDOT nanocrystal in highly conductive PEDOT: ...
# 11  Polymer solar cells based on inkjet-printed PE...
# 12  Highly conductive PEDOT: PSS nanofibrils induc...
# 13  PEDOT/PSS: synthesis, characterization, proper...
# 14  Highly conductive PEDOT: PSS electrode by simp...
# 15  Highly conductive and transparent PEDOT: PSS f...
# 16  Enhancement of thermoelectric properties of PE...
# 17  Review on application of PEDOTs and PEDOT: PSS...
# 18  A morphological model for the solvent‐enhanced...
# 19  Photoelectron spectroscopy of thin films of PE...
# 20  Influence of thermal treatment on the conducti...
# 21  Modification of PEDOT: PSS as hole injection l...
# 22  PEDOT: PSS films with significantly enhanced c...
# 23  Highly conductive PEDOT: PSS electrode with op...
# 24  Anisotropic hopping conduction in spin-coated ...
# 25  The origin of the high conductivity of poly (3...
# 26  Electronic properties of transparent conductiv...
# 27  Three-dimensional inhomogeneities in PEDOT: PS...
# 28  Promising thermoelectric properties of commerc...
# 29  Effective approaches to improve the electrical...
# 30  Morphological and electronic consequences of m...
# 31  Evolution of nanomorphology and anisotropic co...
# 32  Neuromorphic functions in PEDOT: PSS organic e...
# 33  Morphological change and mobility enhancement ...
# 34  Effects of thickness and thermal annealing of ...
# 35  Orthogonal patterning of PEDOT: PSS for organi...
# 36  Highly conductive PEDOT/PSS microfibers fabric...
# 37  Effects of layer thickness and annealing of PE...
# 38  Optical and electrical properties of efficienc...
# 39            Electrically driven PEDOT/PSS actuators
# 40  Electrical characterization of PEDOT: PSS beyo...
# 41  Mechanical flexibility of transparent PEDOT: P...
# 42  “Secondary doping” methods to significantly en...
# 43  Piezoresistive behaviour of flexible PEDOT: PS...
# 44  Enhancement of the thermoelectric properties o...
# 45  Ultra-thin conductive free-standing PEDOT/PSS ...
# 46  Thermoelectric power factor optimization in PE...
# 47  Enhanced thermoelectric properties of PEDOT: P...
# 48  High-efficiency ITO-free polymer solar cells u...
# 49  Low-cost and flexible printed graphene–PEDOT: ...
# 50  Spray-deposited PEDOT: PSS for inverted organi...
# 51  Transparent conductive electrodes from graphen...
# 52  High-efficiency hybrid solar cells by nanostru...
# 53  Influence of ionic liquids on the electrical c...
# 54  Spray coated high-conductivity PEDOT: PSS tran...
# 55  PEDOT: PSS films—Effect of organic solvent add...
# 56  Effect of solvent on PEDOT/PSS nanometer-scale...
# 57  Why does the electrical conductivity in PEDOT:...
# 58  The changing face of PEDOT: PSS films: substra...
# 59  Influence of doped PEDOT: PSS on the performan...
#
#                                                   pub  year
# 0    Advanced Functional Materials 19, no. 8 (2009...  2009
# 1    Electrochemistry Communications 10, no. 10 (2...  2008
# 2      Advanced Materials 19, no. 9 (2007): 1196-1200  2007
# 3        Organic electronics 7, no. 5 (2006): 387-396  2006
# 4        Organic electronics 9, no. 5 (2008): 727-734  2008
# 5         Organic Electronics 10, no. 1 (2009): 61-66  2009
# 6            Synthetic metals 139, no. 1 (2003): 1-10  2003
# 7       Synthetic Metals 159, no. 5-6 (2009): 473-479  2009
# 8    Chemical Physics Letters 394, no. 4-6 (2004):...  2004
# 9       Thin Solid Films 354, no. 1-2 (1999): 129-135  1999
# 10         Macromolecules 45, no. 9 (2012): 3859-3865  2012
# 11      Organic Electronics 10, no. 3 (2009): 536-542  2009
# 12    Advanced materials 26, no. 14 (2014): 2268-2272  2014
# 13                                             (2003)  2003
# 14   Energy & environmental science 5, no. 11 (201...  2012
# 15   Advanced functional materials 22, no. 2 (2012...  2012
# 16                 Scientific reports 6 (2016): 18805  2016
# 17   Journal of Materials Science: Materials in El...  2015
# 18   Advanced Functional Materials 18, no. 6 (2008...  2008
# 19   Journal of Electron Spectroscopy and Related ...  2001
# 20        Synthetic Metals 139, no. 3 (2003): 569-572  2003
# 21   physica status solidi (a) 201, no. 6 (2004): ...  2004
# 22   Journal of Materials Chemistry 21, no. 13 (20...  2011
# 23   Advanced Functional Materials 21, no. 6 (2011...  2011
# 24         Physical review B 76, no. 8 (2007): 085208  2007
# 25   Chemistry of Materials 18, no. 18 (2006): 435...  2006
# 26   Chemistry of Materials 24, no. 2 (2012): 373-382  2012
# 27   The Journal of Physical Chemistry B 108, no. ...  2004
# 28   ACS applied materials & interfaces 2, no. 11 ...  2010
# 29   Advanced Electronic Materials 1, no. 4 (2015)...  2015
# 30                Polymer 46, no. 8 (2005): 2573-2578  2005
# 31   Journal of Materials Chemistry 19, no. 47 (20...  2009
# 32    Advanced Materials 27, no. 44 (2015): 7176-7180  2015
# 33    Advanced materials 25, no. 20 (2013): 2831-2836  2013
# 34      Organic Electronics 10, no. 1 (2009): 205-209  2009
# 35    Advanced Materials 21, no. 22 (2009): 2314-2317  2009
# 36   European Polymer Journal 45, no. 1 (2009): 25...  2009
# 37        Macromolecules 42, no. 17 (2009): 6741-6747  2009
# 38   Journal of Materials Chemistry 21, no. 41 (20...  2011
# 39   Synthetic Metals 159, no. 21-22 (2009): 2233-...  2009
# 40   Sensors and Actuators B: Chemical 143, no. 1 ...  2009
# 41   Solar Energy Materials and Solar Cells 95, no...  2011
# 42                 Displays 34, no. 5 (2013): 423-436  2013
# 43   Sensors and Actuators B: Chemical 139, no. 2 ...  2009
# 44   Journal of Materials Chemistry A 1, no. 26 (2...  2013
# 45          Soft Matter 7, no. 22 (2011): 10642-10650  2011
# 46   Physical Chemistry Chemical Physics 15, no. 1...  2013
# 47   Journal of Materials Chemistry A 2, no. 18 (2...  2014
# 48   Energy & Environmental Science 6, no. 6 (2013...  2013
# 49   Organic Electronics 15, no. 11 (2014): 2971-2981  2014
# 50   Solar Energy Materials and Solar Cells 94, no...  2010
# 51       Advanced Materials 27, no. 4 (2015): 669-675  2015
# 52   Journal of Materials Chemistry A 2, no. 7 (20...  2014
# 53   Chemistry of materials 19, no. 9 (2007): 2147...  2007
# 54   Solar Energy Materials and Solar Cells 110 (2...  2013
# 55   Synthetic metals 159, no. 21-22 (2009): 2237-...  2009
# 56   Synthetic Metals 159, no. 21-22 (2009): 2225-...  2009
# 57   Journal of polymer science part B: polymer ph...  2012
# 58   The Journal of Physical Chemistry C 112, no. ...  2008
# 59   Solar Energy Materials and Solar Cells 95, no...  2011

# %% [markdown]
# ## Export dataframe to file

# %%
ssm.results_to_file(df, topic)

# %%
'''
elems = browser.find_elements_by_xpath("//a[@href]")
for elem in elems:
    print(elem.get_attribute("href"))
    print(elem.get_attribute("id"))
    print(elem.
    '''
# Out:
# '\nelems = browser.find_elements_by_xpath("//a[@href]")\nfor elem in elems:\n    print(elem.get_attribute("href"))\n    print(elem.get_attribute("id"))\n    print(elem.\n    '

# %%
# get list of unique div classes on the page
#sorted(list(set([a.get_attribute('class') for a in browser.find_elements_by_tag_name('div')])))
